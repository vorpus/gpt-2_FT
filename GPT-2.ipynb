# %% [markdown]
# ![Constructive](https://imgs.xkcd.com/comics/constructive.png)

# %% [markdown]
# Setup:
#
# 1) Make sure GPU is enabled, go to edit->notebook settings->Hardware Accelerator GPU
#
# 2) make a copy to your google drive, click on copy to drive in panel

# %% [markdown]
# Note: colab will reset after 12 hours make sure to save your model checkpoints to google drive around 10-11 hours mark or before, then go to runtime->reset all runtimes. Now copy your train model back into colab and start training again from the previous checkpoint.

# %% [markdown]
# clone and cd into repo

# %%
#!git clone https://github.com/nshepperd/gpt-2.git
# !git clone https://github.com/AmbiguousError/gpt-2_FT.git
# Out:
# Cloning into 'gpt-2_FT'...
# remote: Enumerating objects: 62, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 274 (delta 8), reused 0 (delta 0), pack-reused 212
# Receiving objects: 100% (274/274), 6.14 MiB | 10.96 MiB/s, done.
# Resolving deltas: 100% (120/120), done.

# %%
cd gpt-2_FT
# Out:
# /content/gpt-2_FT

# %% [markdown]
# install requirements

# %%
# !pip3 install -r requirements.txt
# Out:
# Collecting fire>=0.1.3 (from -r requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/5a/b7/205702f348aab198baecd1d8344a90748cb68f53bdcd1cc30cbc08e47d3e/fire-0.1.3.tar.gz
# Collecting regex==2017.4.5 (from -r requirements.txt (line 2))
#   Downloading https://files.pythonhosted.org/packages/36/62/c0c0d762ffd4ffaf39f372eb8561b8d491a11ace5a7884610424a8b40f95/regex-2017.04.05.tar.gz (601kB)
#     100% |████████████████████████████████| 604kB 22.0MB/s
# Collecting requests==2.21.0 (from -r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/7d/e3/20f3d364d6c8e5d2353c72a67778eb189176f08e873c9900e10c0287b84b/requests-2.21.0-py2.py3-none-any.whl (57kB)
#     100% |████████████████████████████████| 61kB 21.0MB/s
# Collecting tqdm==4.31.1 (from -r requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/6c/4b/c38b5144cf167c4f52288517436ccafefe9dc01b8d1c190e18a6b154cd4a/tqdm-4.31.1-py2.py3-none-any.whl (48kB)
#     100% |████████████████████████████████| 51kB 21.4MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from fire>=0.1.3->-r requirements.txt (line 1)) (1.11.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests==2.21.0->-r requirements.txt (line 3)) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests==2.21.0->-r requirements.txt (line 3)) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests==2.21.0->-r requirements.txt (line 3)) (2019.3.9)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests==2.21.0->-r requirements.txt (line 3)) (2.6)
# Building wheels for collected packages: fire, regex
#   Building wheel for fire (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/2a/1a/4d/6b30377c3051e76559d1185c1dbbfff15aed31f87acdd14c22
#   Building wheel for regex (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/75/07/38/3c16b529d50cb4e0cd3dbc7b75cece8a09c132692c74450b01
# Successfully built fire regex
# spacy 2.0.18 has requirement numpy>=1.15.0, but you'll have numpy 1.14.6 which is incompatible.
# spacy 2.0.18 has requirement regex==2018.01.10, but you'll have regex 2017.4.5 which is incompatible.
# google-colab 1.0.0 has requirement requests~=2.18.0, but you'll have requests 2.21.0 which is incompatible.
# featuretools 0.4.1 has requirement pandas>=0.23.0, but you'll have pandas 0.22.0 which is incompatible.
# fastai 1.0.50.post1 has requirement numpy>=1.15, but you'll have numpy 1.14.6 which is incompatible.
# datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# Installing collected packages: fire, regex, requests, tqdm
#   Found existing installation: regex 2018.1.10
#     Uninstalling regex-2018.1.10:
#       Successfully uninstalled regex-2018.1.10
#   Found existing installation: requests 2.18.4
#     Uninstalling requests-2.18.4:
#       Successfully uninstalled requests-2.18.4
#   Found existing installation: tqdm 4.28.1
#     Uninstalling tqdm-4.28.1:
#       Successfully uninstalled tqdm-4.28.1
# Successfully installed fire-0.1.3 regex-2017.4.5 requests-2.21.0 tqdm-4.31.1

# %% [markdown]
# mount drive to access google drive for saving and accessing checkpoints later

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# *download* the model

# %%
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
pwd
# Out:
# '/content/gpt-2_FT'

# %%
# !python3 download_model.py 117M
# Out:
# Fetching checkpoint: 1.00kit [00:00, 562kit/s]
# Fetching encoder.json: 1.04Mit [00:00, 35.4Mit/s]
# Fetching hparams.json: 1.00kit [00:00, 556kit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:10, 49.6Mit/s]
# Fetching model.ckpt.index: 6.00kit [00:00, 3.56Mit/s]
# Fetching model.ckpt.meta: 472kit [00:00, 31.4Mit/s]
# Fetching vocab.bpe: 457kit [00:00, 33.6Mit/s]

# %%
# !export PYTHONIOENCODING=UTF-8

# %% [markdown]
# fetch checkpoints if you have them saved in google drive

# %%
# !cp -r /content/drive/My\ Drive/poetry/ /content/gpt-2/

# %% [markdown]
# lets get our text to train on, in this case from project gutenberg, A Tale of Two Cities, by Charles Dickens

# %%
# !wget https://www.gutenberg.org/files/98/98-0.txt

# %% [markdown]
# Join and encode text files

# %%
# !PYTHONPATH=src ./encode.py /content/drive/My\ Drive/poetry/ /content/gpt-2_FT/joined.txt.npz
# Out:
# Reading files
# 100% 49/49 [00:11<00:00,  4.77it/s]
# Writing /content/gpt-2_FT/joined.txt.npz

# %% [markdown]
# start training

# %%
# !PYTHONPATH=src ./train.py --dataset /content/gpt-2_FT/joined.txt.npz
# Out:
# 2019-03-31 07:16:19.926330: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-03-31 07:16:19.926799: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x23f9760 executing computations on platform Host. Devices:
# 2019-03-31 07:16:19.926837: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-03-31 07:16:20.109800: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-03-31 07:16:20.110362: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x23f8f20 executing computations on platform CUDA. Devices:
# 2019-03-31 07:16:20.110399: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2019-03-31 07:16:20.110816: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2019-03-31 07:16:20.110850: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-03-31 07:16:21.556884: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-03-31 07:16:21.556954: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-03-31 07:16:21.556986: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-03-31 07:16:21.557339: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10754 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /content/gpt-2_FT/src/sample.py:51: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /content/gpt-2_FT/src/sample.py:53: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.random.categorical instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Loading checkpoint models/117M/model.ckpt
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# Loading dataset...
# 100% 1/1 [00:00<00:00,  9.62it/s]
# dataset has 1886412 tokens
# Training...
# 2019-03-31 07:16:55.967960: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# [1 | 13.13] loss=2.61 avg=2.61
# [2 | 17.40] loss=2.99 avg=2.80
# [3 | 21.67] loss=2.97 avg=2.86
# [4 | 25.95] loss=3.82 avg=3.10
# [5 | 30.24] loss=3.96 avg=3.28
# [6 | 34.51] loss=3.48 avg=3.31
# [7 | 38.79] loss=3.48 avg=3.34
# [8 | 43.06] loss=2.84 avg=3.27
# [9 | 47.33] loss=3.54 avg=3.30
# [10 | 51.60] loss=2.75 avg=3.24
# [11 | 55.88] loss=3.65 avg=3.28
# [12 | 60.18] loss=3.06 avg=3.26
# [13 | 64.48] loss=2.63 avg=3.21
# [14 | 68.77] loss=3.10 avg=3.20
# [15 | 73.07] loss=2.68 avg=3.17
# [16 | 77.36] loss=2.92 avg=3.15
# [17 | 81.66] loss=2.93 avg=3.14
# [18 | 85.96] loss=2.95 avg=3.12
# [19 | 90.25] loss=3.28 avg=3.13
# [20 | 94.54] loss=3.34 avg=3.14
# [21 | 98.82] loss=2.50 avg=3.11
# [22 | 103.13] loss=3.41 avg=3.13
# [23 | 107.45] loss=3.21 avg=3.13
# [24 | 111.77] loss=2.72 avg=3.11
# [25 | 116.06] loss=3.30 avg=3.12
# [26 | 120.37] loss=3.14 avg=3.12
# [27 | 124.65] loss=2.49 avg=3.09
# [28 | 128.95] loss=3.45 avg=3.11
# [29 | 133.23] loss=3.25 avg=3.11
# [30 | 137.53] loss=2.97 avg=3.11
# [31 | 141.82] loss=2.95 avg=3.10
# [32 | 146.12] loss=3.08 avg=3.10
# [33 | 150.41] loss=3.69 avg=3.12
# [34 | 154.71] loss=3.18 avg=3.12
# [35 | 159.00] loss=2.39 avg=3.10
# [36 | 163.29] loss=1.96 avg=3.06
# [37 | 167.58] loss=2.63 avg=3.05
# [38 | 171.90] loss=3.29 avg=3.06
# [39 | 176.22] loss=2.79 avg=3.05
# [40 | 180.53] loss=2.89 avg=3.04
# [41 | 184.83] loss=2.74 avg=3.03
# [42 | 189.14] loss=2.46 avg=3.02
# [43 | 193.41] loss=2.51 avg=3.00
# [44 | 197.70] loss=2.57 avg=2.99
# [45 | 201.99] loss=3.10 avg=2.99
# [46 | 206.32] loss=3.47 avg=3.01
# [47 | 210.65] loss=2.47 avg=2.99
# [48 | 214.96] loss=2.79 avg=2.99
# [49 | 219.28] loss=3.03 avg=2.99
# [50 | 223.59] loss=3.23 avg=2.99
# [51 | 227.90] loss=2.63 avg=2.98
# [52 | 232.21] loss=2.97 avg=2.98
# [53 | 236.53] loss=2.72 avg=2.98
# [54 | 240.85] loss=3.36 avg=2.99
# [55 | 245.16] loss=3.01 avg=2.99
# [56 | 249.46] loss=2.55 avg=2.98
# [57 | 253.76] loss=3.10 avg=2.98
# [58 | 258.05] loss=2.63 avg=2.97
# [59 | 262.35] loss=3.15 avg=2.98
# [60 | 266.65] loss=3.19 avg=2.98
# [61 | 270.96] loss=2.84 avg=2.98
# [62 | 275.27] loss=2.38 avg=2.97
# [63 | 279.56] loss=2.82 avg=2.96
# [64 | 283.85] loss=3.36 avg=2.97
# [65 | 288.15] loss=3.11 avg=2.97
# [66 | 292.44] loss=3.42 avg=2.98
# [67 | 296.75] loss=3.16 avg=2.99
# [68 | 301.04] loss=2.51 avg=2.98
# [69 | 305.32] loss=3.03 avg=2.98
# [70 | 309.61] loss=3.64 avg=2.99
# [71 | 313.92] loss=3.02 avg=2.99
# [72 | 318.22] loss=3.32 avg=3.00
# [73 | 322.50] loss=2.35 avg=2.99
# [74 | 326.79] loss=3.11 avg=2.99
# [75 | 331.08] loss=2.82 avg=2.98
# [76 | 335.39] loss=2.93 avg=2.98
# [77 | 339.71] loss=3.59 avg=2.99
# [78 | 344.01] loss=2.64 avg=2.99
# [79 | 348.29] loss=2.70 avg=2.98
# [80 | 352.57] loss=3.05 avg=2.98
# [81 | 356.85] loss=2.18 avg=2.97
# [82 | 361.12] loss=2.80 avg=2.97
# [83 | 365.44] loss=2.65 avg=2.96
# [84 | 369.74] loss=2.48 avg=2.95
# [85 | 374.05] loss=2.96 avg=2.95
# [86 | 378.35] loss=3.00 avg=2.95
# [87 | 382.64] loss=3.13 avg=2.96
# [88 | 386.92] loss=3.12 avg=2.96
# [89 | 391.21] loss=2.72 avg=2.96
# [90 | 395.50] loss=3.47 avg=2.96
# [91 | 399.81] loss=3.48 avg=2.97
# [92 | 404.10] loss=3.43 avg=2.98
# [93 | 408.39] loss=3.27 avg=2.99
# [94 | 412.70] loss=2.57 avg=2.98
# [95 | 416.99] loss=2.85 avg=2.98
# [96 | 421.28] loss=2.79 avg=2.97
# [97 | 425.56] loss=3.24 avg=2.98
# [98 | 429.87] loss=3.10 avg=2.98
# [99 | 434.16] loss=3.26 avg=2.98
# ======== SAMPLE 1 ========
#  hear them be with me, I'mma show him
# And he'll see me up here to try and find me where he can
# And he'll see me up here to try to find me where all the things he can do for me
# And he'll show them up here, he'll show them down there,
# And he'll see them come back down here, just me and them,
# But if he just goes down to the lake, I'mma catch him and
# And I'll go down here and show him the lake,
# Then I'll find him up here to try and find me where he can
# And he'll show them up here, he'll show them down there,
# And he'll show them come back down here, just me and them,
# But if he just goes down, just me and them,
# And he'll see them come back down here, just me and them,
# But if he just goes down, just me and them,
# And he'll see them come back down here, just me and them,
# But if he just goes down, just me and them,
# And the only thing he can see
# And he'll see me up there to try and find me where he can
# And he'll see me up here to try and find me, where he can
# Now, I'm going home but I'm still in the middle of them
# And I'm going home to try and find me where he can
# And I'm in the middle of them
# And I'm not going home to try and find me,
# I'm in the middle of them
# And I'm not going home to try and find me,
# I'm not going home to try and find me,
# That's all I can do for you, but I'm not just leaving them with me
# It's not just me, it's all I'm feeling
# And it's not just me, it's all I was born through you, the only thing that I ever felt
# So when you're up there in the middle of me, but you never left
# I know your soul's not gone
# My spirit is alive and strong
# I'm just taking you back where you left
# And I'm going back home and I'm not leaving you
# I'm just taking you back where you left
# And I'm on my way home, my spirit's all still alive
# And I'm not too far away
# Don't try to break me
# I'm taking you back, you're still in the middle, you aren't gone
# I'm not too far away from you,
# It'll be alright
# So when you're up there in the middle of me
# But you never left
# I'm not too far away
# Do I look like the one I used to be, I don't look like that now, don't I look like that now, don't I look like that now?
#
# Don't try to break me
# I'm taking you back, you're still in the middle, you aren't gone
# I'm not too far away
# Do I look like the one I used to be, I don't look like that now, don't I look like that now, don't I look like that now?
# Don't try to break me
# I'm still in the middle of me, I'm not going home, I'm not leaving them with me
# I'm not going home to try and find me where he can
# And he'll see me up here to try and find me where he can
# And he'll see me up here to try and find me where he can
# And he'll see me up here, just me and them,
# But if he just goes down, just me and them,
# And he'll see them come back down here, just me and them,
# But if he just goes down, just me and them,
# And he'll see them come back down here, just me and them,
# But if he just goes down, just me and them,
# And he'll see them come back down here, just me and them
# But if he just goes down, just me and them,
# And he'll see them come back down here, just me and them,
# And he'll see them come back down here, just me and them,
# And he'll see them come back down here, just me and them,
# 'Cause I didn't know
# I never had my own way
# The way you did
# But I never had my own way
# What you taught me
# I used to love you
# I used to love you
# You taught me so
# You taught me so
# You taught me so
# You taught me so
# You taught me so
# You taught me so
# You taught me so
# You taught me so
# You taught me so
# You taught me so
# I used to love you
# I used to love you
# You taught me so
# You taught me so
# You
#
# [100 | 457.55] loss=2.81 avg=2.98
# [101 | 461.84] loss=2.65 avg=2.98
# [102 | 466.13] loss=2.83 avg=2.97
# [103 | 470.41] loss=3.14 avg=2.98
# [104 | 474.69] loss=3.22 avg=2.98
# [105 | 478.98] loss=2.26 avg=2.97
# [106 | 483.28] loss=3.37 avg=2.98
# [107 | 487.57] loss=3.36 avg=2.98
# [108 | 491.86] loss=2.65 avg=2.98
# [109 | 496.15] loss=3.33 avg=2.98
# [110 | 500.44] loss=2.95 avg=2.98
# [111 | 504.75] loss=2.66 avg=2.98
# [112 | 509.05] loss=3.62 avg=2.99
# [113 | 513.34] loss=2.53 avg=2.98
# [114 | 517.65] loss=2.77 avg=2.98
# [115 | 521.94] loss=3.31 avg=2.98
# [116 | 526.24] loss=2.40 avg=2.97
# [117 | 530.54] loss=2.78 avg=2.97
# [118 | 534.84] loss=2.86 avg=2.97
# [119 | 539.13] loss=3.03 avg=2.97
# [120 | 543.43] loss=3.57 avg=2.98
# [121 | 547.73] loss=2.58 avg=2.97
# [122 | 552.03] loss=2.67 avg=2.97
# [123 | 556.32] loss=3.03 avg=2.97
# [124 | 560.60] loss=3.56 avg=2.98
# [125 | 564.93] loss=2.43 avg=2.97
# [126 | 569.24] loss=2.88 avg=2.97
# [127 | 573.55] loss=2.04 avg=2.96
# [128 | 577.87] loss=2.95 avg=2.95
# [129 | 582.18] loss=2.30 avg=2.95
# [130 | 586.49] loss=2.78 avg=2.94
# [131 | 590.78] loss=2.38 avg=2.94
# [132 | 595.09] loss=2.37 avg=2.93
# [133 | 599.38] loss=2.71 avg=2.93
# [134 | 603.66] loss=2.62 avg=2.92
# [135 | 607.97] loss=3.50 avg=2.93
# [136 | 612.27] loss=2.84 avg=2.93
# [137 | 616.55] loss=2.94 avg=2.93
# [138 | 620.85] loss=3.29 avg=2.93
# [139 | 625.17] loss=2.82 avg=2.93
# [140 | 629.46] loss=2.35 avg=2.92
# [141 | 633.77] loss=3.59 avg=2.93
# [142 | 638.07] loss=2.63 avg=2.93
# [143 | 642.38] loss=3.28 avg=2.93
# [144 | 646.66] loss=2.70 avg=2.93
# [145 | 650.96] loss=2.78 avg=2.93
# [146 | 655.26] loss=2.57 avg=2.92
# [147 | 659.58] loss=2.80 avg=2.92
# [148 | 663.88] loss=2.08 avg=2.91
# [149 | 668.20] loss=3.14 avg=2.91
# [150 | 672.52] loss=2.93 avg=2.91
# [151 | 676.82] loss=3.78 avg=2.92
# [152 | 681.12] loss=2.64 avg=2.92
# [153 | 685.42] loss=3.03 avg=2.92
# [154 | 689.70] loss=2.39 avg=2.92
# [155 | 693.99] loss=2.53 avg=2.91
# [156 | 698.28] loss=2.85 avg=2.91
# [157 | 702.56] loss=2.31 avg=2.90
# [158 | 706.85] loss=3.06 avg=2.90
# [159 | 711.13] loss=2.79 avg=2.90
# [160 | 715.41] loss=3.29 avg=2.91
# [161 | 719.69] loss=3.07 avg=2.91
# [162 | 723.97] loss=2.46 avg=2.90
# [163 | 728.26] loss=2.92 avg=2.90
# [164 | 732.54] loss=3.42 avg=2.91
# [165 | 736.84] loss=3.21 avg=2.91
# [166 | 741.12] loss=2.63 avg=2.91
# [167 | 745.42] loss=3.08 avg=2.91
# [168 | 749.70] loss=2.55 avg=2.91
# [169 | 754.00] loss=2.76 avg=2.91
# [170 | 758.29] loss=2.26 avg=2.90
# [171 | 762.57] loss=2.70 avg=2.90
# [172 | 766.86] loss=3.02 avg=2.90
# [173 | 771.14] loss=3.32 avg=2.90
# [174 | 775.43] loss=3.33 avg=2.91
# [175 | 779.72] loss=2.65 avg=2.91
# [176 | 784.01] loss=3.15 avg=2.91
# [177 | 788.33] loss=2.76 avg=2.91
# [178 | 792.63] loss=2.51 avg=2.90
# [179 | 796.93] loss=2.71 avg=2.90
# [180 | 801.23] loss=2.90 avg=2.90
# [181 | 805.53] loss=2.22 avg=2.89
# [182 | 809.83] loss=2.77 avg=2.89
# [183 | 814.14] loss=2.72 avg=2.89
# [184 | 818.44] loss=2.80 avg=2.89
# [185 | 822.74] loss=2.13 avg=2.88
# [186 | 827.04] loss=2.97 avg=2.88
# [187 | 831.34] loss=2.72 avg=2.88
# [188 | 835.63] loss=2.88 avg=2.88
# [189 | 839.94] loss=2.70 avg=2.87
# [190 | 844.25] loss=2.97 avg=2.88
# [191 | 848.54] loss=2.55 avg=2.87
# [192 | 852.83] loss=2.78 avg=2.87
# [193 | 857.11] loss=2.47 avg=2.87
# [194 | 861.40] loss=2.65 avg=2.86
# [195 | 865.69] loss=2.16 avg=2.86
# [196 | 869.97] loss=2.42 avg=2.85
# [197 | 874.26] loss=3.22 avg=2.85
# [198 | 878.56] loss=3.32 avg=2.86
# [199 | 882.86] loss=2.84 avg=2.86
# ======== SAMPLE 1 ========
#  Bone
# To you, to me, I'm ready
# And if you're ready to hear me (You know I can hear you)
# And if you're ready to hear me
# I'm ready
# Let's go
# I'm ready
# I'm ready (I'm ready)
# I'm ready
# I'm ready
# I'm ready (I'm ready)
# I'm ready
# I'm ready
# I'm ready (I'm ready)
# I'm ready
# I'm ready
# I'm ready (I'm ready)
# I'm ready
# I'm ready (I'm ready)
# I'm ready
# I'm ready
# I'm ready
# I'm ready (I'm ready)
# I'm ready
# I'm ready
# I'm ready
# I'm ready (I'm ready)
# I'm ready
# Cuz I'm ready
# I'm ready (I'm ready)
# I'm ready
# Cuz I'm ready
# I'm ready (I'm ready)
# I'm ready
# Cuz I'm ready
# I'm ready (I'm ready)
# I'm ready
# I'm ready
# I'm ready
# I'm ready
# I'm ready (I'm ready)
# I'm ready
# I'm ready (I'm ready)
# I'm ready (I'm ready)
# I'm ready
# I'm ready
# Cuz I'm ready (I'm ready)
# I'm ready (I'm ready)
# I'm ready (I'm ready)
# I'm ready
# I'm ready (I'm ready)
# I'm ready
# I'm ready
# I'm ready
# I'm ready (I'm ready)
# I'm ready We all know that when we get it
# It does not make no difference
# To us
#
# What we do
#
# What we are,
#
# We are,
#
# But when you are out here
# And you don't have time
# You know we will
# We'll be there
#
# If we can find the strength
# To get it right
# And when we're ready
#
# Who knows what will come
# We all know
#  That we don't know
# That we won't believe
# That we
#
# And we will
#
# And we will
#
# (We're ready)
# We are,
#
# We are,
# But when you are
# In the air,
#
# So many times
# You just won't believe
# That we will be there (we're ready).
# We,
#
# We are,
# But when you
# In the air
# And
#
# You just won't?
#
# We will
#
# We are,
#
# But when you are
# In the air
#
# And
# You just won't?
#
# We will
#
# We will,
#
# But when you're out here
# (We're ready)
# We'll be there
#
# We'll be there
#
# So many times,
#
# Do we know
# That we won't believe
# That we
# (We're ready)
#
# We have got it
# (We're ready)
# We got it
#
# We'll
#
# (We're ready)
# We will
# We will,
#
# But
# when you are
# In the air
# (We're ready)
#
# We'll
#
# (We're ready)
# That's the one thing
# We're ready to do
# (We're ready)
# We'll
#
# (We're ready)
# We will,
#
# But when you're in the air
#
# (We're ready)
#
# We will,
#
# We will,
#
# But when you're
# In the air
# When you're out
# (We'll be ready)
#
# We,
#
# (We'll be ready)
# We'll
#
# (We'll be ready)
# We'll
#
# (We'll be ready)
# 'Cause,
# (We'll be ready)
# We'll
#
# (We'll be ready)
# We'll,
#
# (We'll be ready)
# We,
#
# We'll,
# (We'll be ready)
# We'll
#
# (We'll be ready, we'll be ready)
# We'll
#
# (We'll be ready)
# We, We are,
# We are,
# We are,
# We are,
# We are,
# We are,
# We are,
# We are,
# (we're ready, we're ready, we're ready!)
# We, We're,
# We are,
# We are,
# (we're ready, we're ready, we're ready)
# We are, We are,
# We are,
# We are,
# (we're ready, we're ready, we're ready)
# We are,
# We are,
# We are,
# We are, We are,
# We are,
# We are, We are,
# We are,
# We are,
# We are,
# We are,
# We are
#
# [200 | 904.34] loss=2.31 avg=2.85
# [201 | 908.62] loss=3.10 avg=2.86
# [202 | 912.91] loss=3.19 avg=2.86
# [203 | 917.20] loss=2.76 avg=2.86
# [204 | 921.52] loss=2.85 avg=2.86
# [205 | 925.81] loss=2.72 avg=2.86
# [206 | 930.10] loss=2.48 avg=2.85
# [207 | 934.39] loss=2.62 avg=2.85
# [208 | 938.68] loss=3.37 avg=2.86
# [209 | 942.96] loss=3.30 avg=2.86
# [210 | 947.25] loss=2.70 avg=2.86
# [211 | 951.54] loss=2.73 avg=2.86
# [212 | 955.84] loss=3.17 avg=2.86
# [213 | 960.14] loss=2.82 avg=2.86
# [214 | 964.42] loss=2.77 avg=2.86
# [215 | 968.70] loss=2.67 avg=2.86
# [216 | 973.00] loss=2.61 avg=2.86
# [217 | 977.30] loss=2.88 avg=2.86
# [218 | 981.58] loss=2.91 avg=2.86
# [219 | 985.86] loss=2.81 avg=2.86
# [220 | 990.15] loss=2.55 avg=2.85
# [221 | 994.44] loss=2.83 avg=2.85
# [222 | 998.73] loss=2.90 avg=2.85
# [223 | 1003.02] loss=2.97 avg=2.85
# [224 | 1007.31] loss=2.76 avg=2.85
# [225 | 1011.59] loss=2.70 avg=2.85
# [226 | 1015.90] loss=2.54 avg=2.85
# [227 | 1020.19] loss=3.11 avg=2.85
# [228 | 1024.49] loss=3.32 avg=2.86
# [229 | 1028.79] loss=2.42 avg=2.85
# [230 | 1033.10] loss=3.00 avg=2.85
# [231 | 1037.39] loss=2.85 avg=2.85
# [232 | 1041.67] loss=2.58 avg=2.85
# [233 | 1045.98] loss=2.51 avg=2.85
# [234 | 1050.28] loss=2.59 avg=2.84
# [235 | 1054.57] loss=2.76 avg=2.84
# [236 | 1058.86] loss=2.35 avg=2.84
# [237 | 1063.18] loss=2.30 avg=2.83
# [238 | 1067.48] loss=3.50 avg=2.84
# [239 | 1071.77] loss=2.80 avg=2.84
# [240 | 1076.07] loss=2.48 avg=2.83
# [241 | 1080.37] loss=2.62 avg=2.83
# [242 | 1084.66] loss=2.82 avg=2.83
# [243 | 1088.95] loss=2.87 avg=2.83
# [244 | 1093.24] loss=2.91 avg=2.83
# [245 | 1097.53] loss=2.68 avg=2.83
# [246 | 1101.83] loss=3.22 avg=2.84
# [247 | 1106.12] loss=2.30 avg=2.83
# [248 | 1110.41] loss=2.61 avg=2.83
# [249 | 1114.70] loss=2.42 avg=2.82
# [250 | 1118.99] loss=2.56 avg=2.82
# [251 | 1123.28] loss=2.86 avg=2.82
# [252 | 1127.57] loss=2.59 avg=2.82
# [253 | 1131.86] loss=3.13 avg=2.82
# [254 | 1136.14] loss=2.71 avg=2.82
# [255 | 1140.44] loss=2.88 avg=2.82
# [256 | 1144.73] loss=2.72 avg=2.82
# [257 | 1149.04] loss=2.16 avg=2.81
# [258 | 1153.35] loss=2.93 avg=2.81
# [259 | 1157.64] loss=3.00 avg=2.82
# [260 | 1161.93] loss=3.28 avg=2.82
# [261 | 1166.21] loss=2.76 avg=2.82
# [262 | 1170.50] loss=2.51 avg=2.82
# [263 | 1174.78] loss=2.68 avg=2.81
# [264 | 1179.06] loss=3.02 avg=2.82
# [265 | 1183.37] loss=2.86 avg=2.82
# [266 | 1187.64] loss=3.43 avg=2.82
# [267 | 1191.92] loss=2.46 avg=2.82
# [268 | 1196.21] loss=3.29 avg=2.83
# [269 | 1200.50] loss=2.75 avg=2.82
# [270 | 1204.81] loss=2.53 avg=2.82
# [271 | 1209.10] loss=3.44 avg=2.83
# [272 | 1213.41] loss=2.73 avg=2.83
# [273 | 1217.70] loss=2.62 avg=2.82
# [274 | 1222.00] loss=3.05 avg=2.83
# [275 | 1226.30] loss=2.99 avg=2.83
# [276 | 1230.58] loss=3.31 avg=2.83
# [277 | 1234.87] loss=3.12 avg=2.84
# [278 | 1239.17] loss=2.74 avg=2.84
# [279 | 1243.47] loss=2.75 avg=2.84
# [280 | 1247.75] loss=3.06 avg=2.84
# [281 | 1252.06] loss=2.61 avg=2.84
# [282 | 1256.34] loss=2.91 avg=2.84
# [283 | 1260.64] loss=2.75 avg=2.84
# [284 | 1264.92] loss=2.93 avg=2.84
# [285 | 1269.22] loss=2.62 avg=2.83
# [286 | 1273.50] loss=2.45 avg=2.83
# [287 | 1277.80] loss=3.02 avg=2.83
# [288 | 1282.10] loss=3.08 avg=2.83
# [289 | 1286.40] loss=2.60 avg=2.83
# [290 | 1290.69] loss=2.77 avg=2.83
# [291 | 1294.98] loss=2.99 avg=2.83
# [292 | 1299.27] loss=2.99 avg=2.83
# [293 | 1303.56] loss=2.67 avg=2.83
# [294 | 1307.86] loss=2.73 avg=2.83
# [295 | 1312.15] loss=2.53 avg=2.83
# [296 | 1316.44] loss=2.73 avg=2.83
# [297 | 1320.73] loss=2.20 avg=2.82
# [298 | 1325.02] loss=2.97 avg=2.82
# [299 | 1329.31] loss=2.86 avg=2.82
# ======== SAMPLE 1 ========
# , the devil takes it to heart)
# I'll spend your money to be my lady (I'll spend yours to be my lady)
# I'll make an alliance (I'll make an alliance)
# I'll stay in love with you (I'll spend yours to be my lady, your lady and my lady)
# And make a vow (I don't want you to leave me alone)
# And I will
# (I'll spend yours to be my lady, your lady and my lady)
# The night will make a fool of me, girl,
# It's a night until I'm in love with you (I'll spend yours to be my lady, your lady and my lady)
# And I'll make a commitment (I don't want you to leave me alone)
# Until I'm in love with you
# And we'll go to heaven together (it will make a fool of me, girl,
# It's a night until I'm in love with you)
# So don't feel bad about it, we can lay it all out together (it will make a fool of me, girl,
# It's a night until I'm in love with you)
# So don't worry about it though, it's already been over enough, girl (it's too late to go in),
# It's a night until I'm in love with you
# And we'll go to heaven together (it will make a fool of me, girl,
# It's a night until I'm in love with you)
# So don't worry about it though, it's already been too late to go in, girl,
# It's a night until I'm in love with you
# And we'll go to heaven together (it will make a fool of me, girl,
# It's a night until I'm in love with you)
# So don't worry about it though, it's already been too late to go in (it's too late to go in), girl,
# It's a night until we die together
# Let me take this opportunity to show my love to you
# Let this time be your time to shine
# (Let me take this opportunity to show my love to you)
# This time be mine for you (Let me tell you this time you are mine for me)
# (Let me tell you this time you are mine for me)
# And I'll show you how to love me (Let me show you how to love me)
# I'll show you how to love me, girl (Let me show you how to love me)
# And I'll show you how to love me, girl (Let me show you how to love me)
# And I'll show you how to love me, girl (Let me show you how to love me) I'll show you how to love me, girl (Let me show you how to love me)
# I'll show you how to love me, girl (Let me show you how to love me)
# I'll show you how to love me, girl I'll show you how to love me, girl
# I'll show you how to love me, girl Girl, you're good for me, baby, I love you, baby
# I know you can love me, but I won't let you slip away, girl
# I know you're good for me, baby I love you, baby
# I know you're good for me, baby I'll show you how to love me (Let me show you how to love me)
# I'll show you how to love me, girl (Let me show you how to love me)
# And I'll show you how to love me, girl I'll show you how to love me, girl (Let me show you how to love me)
# I'll show you how to love me, girl I'll show you how to love me (Let me show you how to love me) I'll show you how to love me, girl (Let me show you how to love me) I'll show you how to love me, girl (Let me show you how to love me)
# I'll show you how to love me, girl (Let me show you how to love me) I'll show you how to love me, girl (Let me show you how to love me)
# I'll show you how to love me, girl (Let me show you how to love me) I'll see you on the other side of the world
# You're good for me, baby, I love you, baby
# I know you're good for me, baby, I love you, baby
# I know you're good for me, baby, I love you, baby I'll show you how to love me (Let me show you how to love me)
# I'll show you how to love me, girl (Let me show you how to love me) I'll show you how to love me, girl
# I'll show you how to love me, girl (Let me show you how to
#
# [300 | 1351.04] loss=3.19 avg=2.83
# [301 | 1355.33] loss=3.22 avg=2.83
# [302 | 1359.62] loss=3.00 avg=2.83
# [303 | 1363.92] loss=3.00 avg=2.83
# [304 | 1368.23] loss=2.60 avg=2.83
# [305 | 1372.52] loss=3.03 avg=2.83
# [306 | 1376.81] loss=2.68 avg=2.83
# [307 | 1381.09] loss=2.68 avg=2.83
# [308 | 1385.38] loss=3.49 avg=2.84
# [309 | 1389.66] loss=3.28 avg=2.84
# [310 | 1393.93] loss=2.09 avg=2.83
# [311 | 1398.23] loss=2.90 avg=2.84
# [312 | 1402.51] loss=2.42 avg=2.83
# [313 | 1406.79] loss=2.74 avg=2.83
# [314 | 1411.09] loss=2.88 avg=2.83
# [315 | 1415.40] loss=2.93 avg=2.83
# [316 | 1419.69] loss=2.88 avg=2.83
# [317 | 1423.97] loss=2.76 avg=2.83
# [318 | 1428.26] loss=2.31 avg=2.83
# [319 | 1432.57] loss=2.67 avg=2.82
# [320 | 1436.86] loss=2.62 avg=2.82
# [321 | 1441.16] loss=2.78 avg=2.82
# [322 | 1445.46] loss=2.76 avg=2.82
# [323 | 1449.74] loss=3.31 avg=2.83
# [324 | 1454.02] loss=2.73 avg=2.83
# [325 | 1458.30] loss=2.78 avg=2.82
# [326 | 1462.58] loss=2.70 avg=2.82
# [327 | 1466.88] loss=2.41 avg=2.82
# [328 | 1471.20] loss=2.89 avg=2.82
# [329 | 1475.49] loss=2.57 avg=2.82
# [330 | 1479.82] loss=3.11 avg=2.82
# [331 | 1484.16] loss=2.30 avg=2.81
# [332 | 1488.45] loss=2.32 avg=2.81
# [333 | 1492.75] loss=2.69 avg=2.81
# [334 | 1497.03] loss=2.74 avg=2.81
# [335 | 1501.36] loss=2.15 avg=2.80
# [336 | 1505.66] loss=2.93 avg=2.80
# [337 | 1509.95] loss=2.40 avg=2.80
# [338 | 1514.26] loss=2.57 avg=2.80
# [339 | 1518.59] loss=2.57 avg=2.79
# [340 | 1522.90] loss=2.65 avg=2.79
# [341 | 1527.21] loss=2.76 avg=2.79
# [342 | 1531.54] loss=2.93 avg=2.79
# [343 | 1535.87] loss=2.98 avg=2.79
# [344 | 1540.18] loss=2.40 avg=2.79
# [345 | 1544.48] loss=2.64 avg=2.79
# [346 | 1548.78] loss=3.00 avg=2.79
# [347 | 1553.11] loss=3.46 avg=2.80
# [348 | 1557.41] loss=2.50 avg=2.80
# [349 | 1561.72] loss=2.40 avg=2.79
# [350 | 1566.01] loss=2.54 avg=2.79
# [351 | 1570.30] loss=3.14 avg=2.79
# [352 | 1574.60] loss=2.81 avg=2.79
# [353 | 1578.91] loss=3.07 avg=2.80
# [354 | 1583.21] loss=2.32 avg=2.79
# [355 | 1587.52] loss=2.68 avg=2.79
# [356 | 1591.81] loss=2.71 avg=2.79
# [357 | 1596.10] loss=2.15 avg=2.78
# [358 | 1600.39] loss=2.93 avg=2.78
# [359 | 1604.70] loss=2.77 avg=2.78
# [360 | 1609.00] loss=2.59 avg=2.78
# [361 | 1613.29] loss=2.54 avg=2.78
# [362 | 1617.60] loss=3.37 avg=2.78
# [363 | 1621.89] loss=2.47 avg=2.78
# [364 | 1626.21] loss=2.59 avg=2.78
# [365 | 1630.52] loss=3.04 avg=2.78
# [366 | 1634.82] loss=2.21 avg=2.78
# [367 | 1639.13] loss=3.12 avg=2.78
# [368 | 1643.43] loss=2.72 avg=2.78
# [369 | 1647.75] loss=2.29 avg=2.77
# [370 | 1652.03] loss=2.84 avg=2.77
# [371 | 1656.33] loss=2.77 avg=2.77
# [372 | 1660.59] loss=2.71 avg=2.77
# [373 | 1664.87] loss=2.60 avg=2.77
# [374 | 1669.15] loss=2.74 avg=2.77
# [375 | 1673.48] loss=2.34 avg=2.77
# [376 | 1677.77] loss=2.89 avg=2.77
# [377 | 1682.06] loss=2.83 avg=2.77
# [378 | 1686.35] loss=2.46 avg=2.77
# [379 | 1690.63] loss=2.31 avg=2.76
# [380 | 1694.92] loss=2.58 avg=2.76
# [381 | 1699.23] loss=2.81 avg=2.76
# [382 | 1703.51] loss=2.88 avg=2.76
# [383 | 1707.81] loss=2.44 avg=2.76
# [384 | 1712.10] loss=2.61 avg=2.76
# [385 | 1716.40] loss=2.76 avg=2.76
# [386 | 1720.69] loss=2.61 avg=2.76
# [387 | 1724.98] loss=2.55 avg=2.75
# [388 | 1729.28] loss=2.73 avg=2.75
# [389 | 1733.58] loss=3.27 avg=2.76
# [390 | 1737.88] loss=2.81 avg=2.76
# [391 | 1742.19] loss=2.61 avg=2.76
# [392 | 1746.47] loss=2.68 avg=2.76
# [393 | 1750.76] loss=2.83 avg=2.76
# [394 | 1755.05] loss=2.43 avg=2.75
# [395 | 1759.34] loss=2.68 avg=2.75
# [396 | 1763.62] loss=3.60 avg=2.76
# [397 | 1767.91] loss=2.77 avg=2.76
# [398 | 1772.22] loss=2.91 avg=2.76
# [399 | 1776.53] loss=2.58 avg=2.76
# ======== SAMPLE 1 ========
#
# The sun always shines green
# The sun always shines green
# The sun always shines green, yeah
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun always shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines red
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun only shines green
# The sun never shines green
# The sun never shines green
# The sun only shines green
# The sun never shines green
# The sun only shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun only shines green
# The sun never shines green
# The sun never shines green
# The sun only shines green
# The sun never shines green
# The sun only shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun only shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun only shines green
# The sun never shines green
# The sun only shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun only shines green
# The sun never shines green
# The sun only shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun only shines green
# The sun only shines green
# The sun only shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun only shines green
# The sun never shines green
# The sun never shines green
# The sun only shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun only shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun only shines green
# The sun only shines green
# The sun never shines green
# The sun never shines green
# The sun only shines green
# The sun never shines green
# The sun never shines green
# The sun only shines green
# The sun never shines green
# The sun never shines green
# The sun only shines green
# The sun only shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun only shines green
# The sun never shines green
# The sun never shines green
# The sun only shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun never shines green
# The sun will always shine green
# The sun will always shine green
# The sun will always shine green
# The sun will always shine green
# The sun will always shine green
# The sun will always shine green
# The sun will always shine green
# The sun will always shine green
# The sun will always shine green
# The sun will always shine green
# The sun will always shine green
# The sun will always shine green
# The sun will always shine green
# The sun will always shine green
# The sun will always shine green
# The sun will always shine green
# The sun will always shine green
# The sun will always shine green
# The sun will always shine green
# The sun will always shine green
# The sun will always shine green
# The sun will always shine green
# The sun will
#
# [400 | 1797.90] loss=3.16 avg=2.77
# [401 | 1802.20] loss=2.48 avg=2.76
# [402 | 1806.52] loss=2.46 avg=2.76
# [403 | 1810.81] loss=2.53 avg=2.76
# [404 | 1815.11] loss=3.05 avg=2.76
# [405 | 1819.40] loss=2.41 avg=2.76
# [406 | 1823.73] loss=2.82 avg=2.76
# [407 | 1828.05] loss=3.07 avg=2.76
# [408 | 1832.35] loss=3.38 avg=2.77
# [409 | 1836.65] loss=2.55 avg=2.76
# [410 | 1840.95] loss=3.02 avg=2.77
# [411 | 1845.26] loss=2.78 avg=2.77
# [412 | 1849.59] loss=3.05 avg=2.77
# [413 | 1853.91] loss=2.59 avg=2.77
# [414 | 1858.23] loss=2.67 avg=2.77
# [415 | 1862.55] loss=2.65 avg=2.77
# [416 | 1866.86] loss=2.73 avg=2.77
# [417 | 1871.17] loss=2.77 avg=2.77
# [418 | 1875.48] loss=2.63 avg=2.76
# [419 | 1879.79] loss=1.99 avg=2.76
# [420 | 1884.11] loss=2.50 avg=2.75
# [421 | 1888.42] loss=2.40 avg=2.75
# [422 | 1892.75] loss=2.18 avg=2.74
# [423 | 1897.08] loss=3.18 avg=2.75
# [424 | 1901.40] loss=2.76 avg=2.75
# [425 | 1905.72] loss=2.88 avg=2.75
# [426 | 1910.04] loss=2.41 avg=2.75
# [427 | 1914.35] loss=2.98 avg=2.75
# [428 | 1918.65] loss=2.98 avg=2.75
# [429 | 1922.96] loss=2.20 avg=2.75
# [430 | 1927.27] loss=2.88 avg=2.75
# [431 | 1931.58] loss=2.67 avg=2.75
# [432 | 1935.89] loss=2.52 avg=2.74
# [433 | 1940.18] loss=2.63 avg=2.74
# [434 | 1944.49] loss=2.81 avg=2.74
# [435 | 1948.79] loss=2.63 avg=2.74
# [436 | 1953.09] loss=2.26 avg=2.74
# [437 | 1957.40] loss=2.52 avg=2.74
# [438 | 1961.71] loss=2.62 avg=2.73
# [439 | 1966.02] loss=2.82 avg=2.73
# [440 | 1970.33] loss=2.19 avg=2.73
# [441 | 1974.64] loss=2.33 avg=2.73
# [442 | 1978.96] loss=2.68 avg=2.72
# [443 | 1983.27] loss=2.78 avg=2.73
# [444 | 1987.58] loss=2.52 avg=2.72
# [445 | 1991.90] loss=2.79 avg=2.72
# [446 | 1996.20] loss=2.65 avg=2.72
# [447 | 2000.50] loss=2.29 avg=2.72
# [448 | 2004.79] loss=2.92 avg=2.72
# [449 | 2009.10] loss=3.19 avg=2.73
# [450 | 2013.37] loss=2.44 avg=2.72
# [451 | 2017.65] loss=2.41 avg=2.72
# [452 | 2021.93] loss=2.61 avg=2.72
# [453 | 2026.21] loss=2.65 avg=2.72
# [454 | 2030.49] loss=2.32 avg=2.71
# [455 | 2034.79] loss=2.83 avg=2.71
# [456 | 2039.08] loss=2.58 avg=2.71
# [457 | 2043.37] loss=2.37 avg=2.71
# [458 | 2047.65] loss=2.83 avg=2.71
# [459 | 2051.96] loss=2.38 avg=2.71
# [460 | 2056.25] loss=2.82 avg=2.71
# [461 | 2060.55] loss=2.90 avg=2.71
# [462 | 2064.85] loss=2.90 avg=2.71
# [463 | 2069.15] loss=2.24 avg=2.71
# [464 | 2073.43] loss=2.62 avg=2.71
# [465 | 2077.71] loss=2.30 avg=2.70
# [466 | 2082.00] loss=2.10 avg=2.70
# [467 | 2086.29] loss=2.91 avg=2.70
# [468 | 2090.57] loss=2.53 avg=2.70
# [469 | 2094.86] loss=2.66 avg=2.70
# [470 | 2099.15] loss=2.84 avg=2.70
# [471 | 2103.43] loss=2.09 avg=2.69
# [472 | 2107.73] loss=2.60 avg=2.69
# [473 | 2112.02] loss=2.90 avg=2.69
# [474 | 2116.30] loss=2.38 avg=2.69
# [475 | 2120.60] loss=2.82 avg=2.69
# [476 | 2124.89] loss=2.34 avg=2.69
# [477 | 2129.19] loss=3.15 avg=2.69
# [478 | 2133.47] loss=2.86 avg=2.69
# [479 | 2137.76] loss=2.21 avg=2.69
# [480 | 2142.05] loss=2.57 avg=2.69
# [481 | 2146.35] loss=2.49 avg=2.69
# [482 | 2150.65] loss=2.31 avg=2.68
# [483 | 2154.94] loss=2.91 avg=2.68
# [484 | 2159.23] loss=2.46 avg=2.68
# [485 | 2163.53] loss=2.19 avg=2.68
# [486 | 2167.83] loss=2.54 avg=2.68
# [487 | 2172.14] loss=2.53 avg=2.67
# [488 | 2176.42] loss=2.97 avg=2.68
# [489 | 2180.71] loss=2.49 avg=2.68
# [490 | 2185.00] loss=2.80 avg=2.68
# [491 | 2189.32] loss=2.89 avg=2.68
# [492 | 2193.62] loss=2.97 avg=2.68
# [493 | 2197.90] loss=2.77 avg=2.68
# [494 | 2202.19] loss=2.95 avg=2.69
# [495 | 2206.50] loss=2.71 avg=2.69
# [496 | 2210.78] loss=2.58 avg=2.68
# [497 | 2215.06] loss=2.74 avg=2.69
# [498 | 2219.35] loss=2.65 avg=2.69
# [499 | 2223.64] loss=2.51 avg=2.68
# ======== SAMPLE 1 ========
#  wear a hat
# I swear you gonna keep on saying "yeah!"
# And I'll stop in the club, put my shoes on
# And when I see your name I'll smile so that it's gonna be worth it
# Yeah, yeah, yeah, yeah, yeah
# And I'll be all you love in the club, in the club
# Oh yeah, yeah, yeah, yeah, yeah
# And I'll leave you on the floor, on the floor you know
# If you don't want me, I'm going to break your heart and I'll leave you on the floor, in the club
# Oh yeah, yeah, yeah, yeah, yeah
# And I'll leave you on the floor, on the floor you know
# If you want me, I'm going to break your heart and I'll leave you on the floor, in the club, in the club
# Oh yeah, yeah, yeah, yeah, yeah
# And I'll leave you on the floor, in the club, in the club
# I'd never leave you, I'd never leave you on the floor, in the club, in the club
# Yeah, yeah, yeah, yeah, yeah, yeah
# And I'll leave you on the floor, in the club, in the club
# Oh, yeah, yeah, yeah, yeah, yeah
# And I'll leave you on the floor, in the club
# Oh, yeah, yeah, yeah, yeah, yeah
# And I'll leave you on the floor, in the club, in the club
# Oh, yeah, yeah, yeah, yeah, yeah
# And I'll leave you on the floor, in the club, in the club
# Oh, yeah, yeah, yeah, yeah, yeah
# And I'll leave you on the floor, in the club
# Oh, yeah, yeah, yeah, yeah, yeah
# And I'll leave you on the floor, in the club, in the club
# Oh, yeah, yeah, yeah, yeah, yeah
# And I'll leave you on the floor, in the club, oh yeah, yeah, yeah, yeah
# And I'll leave you on the floor, in the club, oh yeah, yeah, yeah, yeah
# And I'll leave you on the floor, in the club, in the club
# Oh, yeah, yeah, yeah, yeah, yeah
# And I'll leave you on the floor, in the club- Oh, yeah, yeah, yeah, yeah, yeah, yeah
# And I'll leave you on the floor, in the club, in the club
# Oh, yeah, yeah, yeah, yeah, yeah
# And I'll leave you on the floor, in the club, in the club
# Oh, yeah, yeah, yeah, yeah, yeah
# And I'll leave you on the floor, in the club, oh yeah, yeah, yeah, yeah
# And I'll leave you on the floor, in the club, in the club, oh yeah, yeah, yeah
# And I'll leave you on the floor, in the club, in the club, oh yeah, yeah, yeah
# And I'll leave you on the floor, in the club, just to say, yeah, yeah
# And I'll leave you on the floor, on the floor, in the club, in the club, just to say, yeah
# And I'll leave you on the floor, and the club, in the club, just to say, yeah
# And I'll leave you on the floor, in the club, just to say, yeah, yeah
# I'm back on the road again 'Cause I'm back on the road again
# Cause I'm back on the road again
# Cause I'm back on the road again
# Cause I'm back on the road again
# Cause I'm back on the road again
# Cause I'm back on the road again
# Cause I'm back on the road again But I'm back on the road again
# Cause I'm back on the road
# Cause I'm back on the road again
# Cause I'm back on the road again But I'm back on the road again
# Cause I'm back on the road
# Cause I'm back on the road again But I'm back on the road again
# Cause I'm back on the road again
# My life's gonna change 'Cause I'm back on the road again
# Cause I'm back on the road
# Cause I'm back on the road again But I'm back on the road again
# Cause I'm back on the road again
# My life's gonna change
# Cause I'm back on the road again
# Cause I'm back on the road again But I'm back on the road again
# Cause I'm back on the road Again I've had enough
# And everything I've done
# Is what should have saved me
# 'Cause I'm back on the road again
# Cause I'm back on the road
# Cause I'm back on the road again
# Cause I'm back on the road again But I'm back on the road
#
# [500 | 2245.03] loss=2.77 avg=2.68
# [501 | 2249.34] loss=2.82 avg=2.69
# [502 | 2253.63] loss=2.81 avg=2.69
# [503 | 2257.92] loss=2.40 avg=2.68
# [504 | 2262.22] loss=2.54 avg=2.68
# [505 | 2266.52] loss=2.84 avg=2.68
# [506 | 2270.82] loss=2.79 avg=2.69
# [507 | 2275.11] loss=2.44 avg=2.68
# [508 | 2279.38] loss=3.06 avg=2.69
# [509 | 2283.67] loss=2.33 avg=2.68
# [510 | 2287.97] loss=2.30 avg=2.68
# [511 | 2292.26] loss=2.49 avg=2.68
# [512 | 2296.55] loss=3.03 avg=2.68
# [513 | 2300.84] loss=2.84 avg=2.68
# [514 | 2305.15] loss=2.47 avg=2.68
# [515 | 2309.45] loss=2.20 avg=2.68
# [516 | 2313.73] loss=2.46 avg=2.67
# [517 | 2318.03] loss=2.24 avg=2.67
# [518 | 2322.32] loss=2.10 avg=2.66
# [519 | 2326.62] loss=3.04 avg=2.67
# [520 | 2330.93] loss=2.96 avg=2.67
# [521 | 2335.23] loss=2.47 avg=2.67
# [522 | 2339.52] loss=2.38 avg=2.66
# [523 | 2343.80] loss=3.17 avg=2.67
# [524 | 2348.10] loss=2.14 avg=2.66
# [525 | 2352.40] loss=2.42 avg=2.66
# [526 | 2356.68] loss=2.82 avg=2.66
# [527 | 2360.96] loss=2.64 avg=2.66
# [528 | 2365.24] loss=2.25 avg=2.66
# [529 | 2369.53] loss=2.83 avg=2.66
# [530 | 2373.81] loss=3.16 avg=2.67
# [531 | 2378.10] loss=2.15 avg=2.66
# [532 | 2382.39] loss=3.16 avg=2.67
# [533 | 2386.67] loss=3.12 avg=2.67
# [534 | 2390.97] loss=2.55 avg=2.67
# [535 | 2395.27] loss=2.68 avg=2.67
# [536 | 2399.57] loss=2.52 avg=2.67
# [537 | 2403.85] loss=3.04 avg=2.67
# [538 | 2408.14] loss=2.51 avg=2.67
# [539 | 2412.44] loss=2.42 avg=2.67
# [540 | 2416.75] loss=2.25 avg=2.66
# [541 | 2421.03] loss=2.53 avg=2.66
# [542 | 2425.33] loss=2.50 avg=2.66
# [543 | 2429.63] loss=2.49 avg=2.66
# [544 | 2433.93] loss=3.13 avg=2.66
# [545 | 2438.22] loss=2.35 avg=2.66
# [546 | 2442.51] loss=2.91 avg=2.66
# [547 | 2446.81] loss=2.44 avg=2.66
# [548 | 2451.08] loss=3.08 avg=2.66
# [549 | 2455.38] loss=2.20 avg=2.66
# [550 | 2459.65] loss=2.45 avg=2.66
# [551 | 2463.93] loss=2.37 avg=2.66
# [552 | 2468.24] loss=2.25 avg=2.65
# [553 | 2472.55] loss=2.27 avg=2.65
# [554 | 2476.87] loss=2.22 avg=2.64
# [555 | 2481.18] loss=2.22 avg=2.64
# [556 | 2485.50] loss=2.49 avg=2.64
# [557 | 2489.80] loss=2.69 avg=2.64
# [558 | 2494.10] loss=2.98 avg=2.64
# [559 | 2498.40] loss=2.57 avg=2.64
# [560 | 2502.69] loss=2.50 avg=2.64
# [561 | 2506.97] loss=2.26 avg=2.64
# [562 | 2511.27] loss=2.96 avg=2.64
# [563 | 2515.57] loss=2.82 avg=2.64
# [564 | 2519.87] loss=2.52 avg=2.64
# [565 | 2524.15] loss=2.65 avg=2.64
# [566 | 2528.44] loss=2.27 avg=2.64
# [567 | 2532.73] loss=2.85 avg=2.64
# [568 | 2537.02] loss=2.27 avg=2.63
# [569 | 2541.30] loss=2.28 avg=2.63
# [570 | 2545.61] loss=2.36 avg=2.63
# [571 | 2549.91] loss=2.39 avg=2.63
# [572 | 2554.19] loss=2.37 avg=2.62
# [573 | 2558.48] loss=2.65 avg=2.62
# [574 | 2562.77] loss=2.82 avg=2.63
# [575 | 2567.07] loss=3.08 avg=2.63
# [576 | 2571.36] loss=2.19 avg=2.63
# [577 | 2575.64] loss=2.41 avg=2.62
# [578 | 2579.92] loss=3.01 avg=2.63
# [579 | 2584.24] loss=2.44 avg=2.63
# [580 | 2588.52] loss=1.68 avg=2.62
# [581 | 2592.81] loss=2.65 avg=2.62
# [582 | 2597.11] loss=2.47 avg=2.61
# [583 | 2601.42] loss=2.12 avg=2.61
# [584 | 2605.73] loss=2.71 avg=2.61
# [585 | 2610.03] loss=2.62 avg=2.61
# [586 | 2614.32] loss=3.14 avg=2.62
# [587 | 2618.62] loss=2.51 avg=2.62
# [588 | 2622.91] loss=2.46 avg=2.61
# [589 | 2627.22] loss=2.09 avg=2.61
# [590 | 2631.51] loss=2.81 avg=2.61
# [591 | 2635.81] loss=2.54 avg=2.61
# [592 | 2640.10] loss=2.57 avg=2.61
# [593 | 2644.39] loss=2.44 avg=2.61
# [594 | 2648.71] loss=2.83 avg=2.61
# [595 | 2653.01] loss=2.30 avg=2.61
# [596 | 2657.31] loss=2.45 avg=2.61
# [597 | 2661.60] loss=2.54 avg=2.60
# [598 | 2665.89] loss=2.58 avg=2.60
# [599 | 2670.19] loss=2.23 avg=2.60
# ======== SAMPLE 1 ========
#  the world, but I got to keep my eyes on you
# (Whoa-ho-oh I know)
# I'm gonna do all the things you tell me to, do
# (Do you hear somebody's voice?) Oh, oh Oh, oh, oh (oh-oh-oh-oh-oh-oh)
# Oh, oh Oh, oh, oh (oh-oh-oh-oh-oh-oh)
# I'll be yours, your little queen of my dreams, oh
# (Oh, oh) Oh Oh
# (Oh, oh) Oh Oh Oh Oh
# Oh, oh, oh (oh-oh-oh-oh-oh-oh)
# I'll be yours, your little queen of my dreams, oh
# (Oh, oh) Oh Oh Oh Oh
# Oh, oh, oh
# (Oh, oh) Oh Oh
# (Oh, oh) [Verse 2]
# My baby, you're mine, you're mine, you're mine, you're mine
# You're still mine, you're mine, you're mine, you're mine
# You're still mine, you're mine, you're mine, you're mine
# You're still mine, you're mine, you're mine, you're mine
# You're still mine, you're mine, you're mine, you're mine
# You're still mine, you're mine, you're mine My baby, you're mine, you're mine, you're mine
# You're still mine, you're mine, you're mine
# You're still mine, you're mine, you're mine
# You're still mine, you're mine, you're mine
# You're still mine, you're mine, you're mine (oh-oh-oh-oh-oh-oh-oh)
# It's your little thing, it's your little thing
# You take my love and it starts to fall and you make me want to be your love, oh
# It's your little thing, it's your little thing
# You take my love and it starts to fall and you make me want to be your love, oh
# It's your little thing, you make me want to be your love
# You make my love and it starts to fall and you make me want to be your love
# Oh, oh, oh, come on and take it, give it to me, give it to me
# You make my love and it starts to fall and you make me want to be your love
# Oh, oh, oh, come on and take it, let's take it, let's take it [Chorus]
# Take it, take it, let me take it, take it, take it (oh)
# Here come the women
# Couple feet in the air
# They're all just looking for you
# You're just holding and you're just kissing
# Giggle, baby, giggle [Verse 3]
# My baby, your are mine, you're mine, you're mine
# You're still mine, you're mine, you're mine
# You're still mine, you're mine, you're mine
# You're still mine, you're mine, you're mine
# You're still mine, you're mine, you're mine
# You're still mine, you're mine, you're mine
# You're still mine, you're mine, you're mine
# You're still mine, you're mine, you're mine
# You're still mine, you're mine, you're mine
# You're still mine, you're mine, you're mine
# We're gonna bring the moon back on top
# Just in case (the moon back on top)
# The last time I saw her
# This time I'll walk up to her back
# Just in case (the last time I saw her)
# We're gonna bring the moon back on top, back over back (woo)
# And we're gonna walk up to her back
# Just in case (the last time I saw her)
# We're gonna bring the moon back on top, back over back (woo) [Verse 4]
# My baby, you're mine, you're mine
# You're still mine, you're mine
# You're still mine, you're mine
# You're still mine, you're mine
# You're still mine, you're mine
# You're still mine, you're mine
# You're still mine, you're mine
# You're still mine, you're mine
#
#
# We were never the same
# This could be a dream
# We were just as lost as you
# We were just as insecure
# And we were so scared
# And if you give me a reason (if you give me a reason)
# And if we were just as bad as you
# And if we were just as bad as you
# Or if you could be someone more than I could ever be
# And if you give me a reason (if you give me a reason)
# And if we were just as
#
# [600 | 2691.53] loss=2.43 avg=2.60
# [601 | 2695.82] loss=2.20 avg=2.59
# [602 | 2700.14] loss=2.54 avg=2.59
# [603 | 2704.45] loss=2.60 avg=2.59
# [604 | 2708.77] loss=2.26 avg=2.59
# [605 | 2713.09] loss=2.59 avg=2.59
# [606 | 2717.40] loss=2.64 avg=2.59
# [607 | 2721.72] loss=3.20 avg=2.60
# [608 | 2726.04] loss=2.92 avg=2.60
# [609 | 2730.33] loss=2.51 avg=2.60
# [610 | 2734.64] loss=2.71 avg=2.60
# [611 | 2738.98] loss=2.22 avg=2.60
# [612 | 2743.29] loss=2.89 avg=2.60
# [613 | 2747.58] loss=2.47 avg=2.60
# [614 | 2751.88] loss=2.07 avg=2.59
# [615 | 2756.20] loss=2.52 avg=2.59
# [616 | 2760.51] loss=2.71 avg=2.59
# [617 | 2764.82] loss=2.75 avg=2.60
# [618 | 2769.13] loss=2.59 avg=2.60
# [619 | 2773.44] loss=2.20 avg=2.59
# [620 | 2777.71] loss=2.59 avg=2.59
# [621 | 2782.00] loss=2.83 avg=2.59
# [622 | 2786.30] loss=2.27 avg=2.59
# [623 | 2790.61] loss=2.74 avg=2.59
# [624 | 2794.91] loss=2.65 avg=2.59
# [625 | 2799.20] loss=2.10 avg=2.59
# [626 | 2803.47] loss=2.44 avg=2.59
# [627 | 2807.76] loss=2.86 avg=2.59
# [628 | 2812.03] loss=2.54 avg=2.59
# [629 | 2816.31] loss=2.57 avg=2.59
# [630 | 2820.61] loss=2.23 avg=2.58
# [631 | 2824.91] loss=2.40 avg=2.58
# [632 | 2829.20] loss=2.25 avg=2.58
# [633 | 2833.48] loss=2.25 avg=2.58
# [634 | 2837.77] loss=2.74 avg=2.58
# [635 | 2842.07] loss=2.52 avg=2.58
# [636 | 2846.35] loss=2.04 avg=2.57
# [637 | 2850.64] loss=3.13 avg=2.58
# [638 | 2854.94] loss=2.56 avg=2.58
# [639 | 2859.25] loss=2.23 avg=2.57
# [640 | 2863.55] loss=2.43 avg=2.57
# [641 | 2867.83] loss=2.67 avg=2.57
# [642 | 2872.11] loss=2.53 avg=2.57
# [643 | 2876.40] loss=2.68 avg=2.57
# [644 | 2880.68] loss=2.65 avg=2.57
# [645 | 2884.98] loss=2.60 avg=2.57
# [646 | 2889.28] loss=2.58 avg=2.58
# [647 | 2893.59] loss=2.56 avg=2.57
# [648 | 2897.90] loss=2.86 avg=2.58
# [649 | 2902.20] loss=2.78 avg=2.58
# [650 | 2906.49] loss=2.42 avg=2.58
# [651 | 2910.79] loss=2.16 avg=2.57
# [652 | 2915.07] loss=2.86 avg=2.58
# [653 | 2919.37] loss=3.07 avg=2.58
# [654 | 2923.65] loss=3.08 avg=2.59
# [655 | 2927.94] loss=2.15 avg=2.58
# [656 | 2932.23] loss=2.70 avg=2.58
# [657 | 2936.52] loss=2.65 avg=2.58
# [658 | 2940.81] loss=2.86 avg=2.59
# [659 | 2945.11] loss=2.59 avg=2.59
# [660 | 2949.40] loss=2.42 avg=2.59
# [661 | 2953.71] loss=2.39 avg=2.58
# [662 | 2958.01] loss=2.34 avg=2.58
# [663 | 2962.30] loss=2.16 avg=2.58
# [664 | 2966.59] loss=2.33 avg=2.57
# [665 | 2970.88] loss=2.46 avg=2.57
# [666 | 2975.19] loss=2.71 avg=2.57
# [667 | 2979.50] loss=2.19 avg=2.57
# [668 | 2983.80] loss=2.45 avg=2.57
# [669 | 2988.09] loss=2.59 avg=2.57
# [670 | 2992.37] loss=2.47 avg=2.57
# ...
# [1504 | 6739.18] loss=1.87 avg=1.96
# [1505 | 6743.49] loss=1.40 avg=1.95
# [1506 | 6747.78] loss=2.43 avg=1.96
# [1507 | 6752.08] loss=1.51 avg=1.95
# [1508 | 6756.36] loss=2.11 avg=1.95
# [1509 | 6760.67] loss=1.43 avg=1.95
# [1510 | 6764.98] loss=1.81 avg=1.95
# [1511 | 6769.27] loss=2.05 avg=1.95
# [1512 | 6773.57] loss=2.12 avg=1.95
# [1513 | 6777.87] loss=1.92 avg=1.95
# [1514 | 6782.18] loss=1.91 avg=1.95
# [1515 | 6786.46] loss=1.87 avg=1.95
# [1516 | 6790.77] loss=1.72 avg=1.95
# [1517 | 6795.07] loss=1.76 avg=1.94
# [1518 | 6799.36] loss=2.00 avg=1.94
# [1519 | 6803.65] loss=1.84 avg=1.94
# [1520 | 6807.94] loss=2.22 avg=1.95
# [1521 | 6812.24] loss=2.00 avg=1.95
# [1522 | 6816.52] loss=1.44 avg=1.94
# [1523 | 6820.81] loss=1.87 avg=1.94
# [1524 | 6825.10] loss=1.70 avg=1.94
# [1525 | 6829.40] loss=1.66 avg=1.94
# [1526 | 6833.72] loss=2.27 avg=1.94
# [1527 | 6838.02] loss=1.49 avg=1.93
# [1528 | 6842.36] loss=1.91 avg=1.93
# [1529 | 6846.67] loss=1.65 avg=1.93
# [1530 | 6850.97] loss=1.62 avg=1.93
# [1531 | 6855.24] loss=2.17 avg=1.93
# [1532 | 6859.54] loss=1.75 avg=1.93
# [1533 | 6863.83] loss=1.56 avg=1.92
# [1534 | 6868.13] loss=1.78 avg=1.92
# [1535 | 6872.42] loss=2.14 avg=1.93
# [1536 | 6876.71] loss=2.14 avg=1.93
# [1537 | 6881.00] loss=1.50 avg=1.92
# [1538 | 6885.31] loss=1.54 avg=1.92
# [1539 | 6889.61] loss=2.47 avg=1.93
# [1540 | 6893.89] loss=1.99 avg=1.93
# [1541 | 6898.18] loss=1.54 avg=1.92
# [1542 | 6902.47] loss=2.13 avg=1.92
# [1543 | 6906.76] loss=1.71 avg=1.92
# [1544 | 6911.06] loss=2.03 avg=1.92
# [1545 | 6915.37] loss=1.91 avg=1.92
# [1546 | 6919.67] loss=2.16 avg=1.93
# [1547 | 6923.96] loss=1.83 avg=1.92
# [1548 | 6928.25] loss=1.59 avg=1.92
# [1549 | 6932.53] loss=1.92 avg=1.92
# [1550 | 6936.83] loss=1.70 avg=1.92
# [1551 | 6941.11] loss=2.59 avg=1.93
# [1552 | 6945.39] loss=2.21 avg=1.93
# [1553 | 6949.69] loss=2.05 avg=1.93
# [1554 | 6953.99] loss=1.89 avg=1.93
# [1555 | 6958.28] loss=1.61 avg=1.93
# [1556 | 6962.57] loss=2.02 avg=1.93
# [1557 | 6966.85] loss=2.01 avg=1.93
# [1558 | 6971.13] loss=1.60 avg=1.92
# [1559 | 6975.44] loss=1.83 avg=1.92
# [1560 | 6979.74] loss=1.51 avg=1.92
# [1561 | 6984.02] loss=2.27 avg=1.92
# [1562 | 6988.31] loss=1.85 avg=1.92
# [1563 | 6992.60] loss=1.89 avg=1.92
# [1564 | 6996.87] loss=1.74 avg=1.92
# [1565 | 7001.17] loss=1.80 avg=1.92
# [1566 | 7005.45] loss=1.65 avg=1.92
# [1567 | 7009.75] loss=1.93 avg=1.92
# [1568 | 7014.03] loss=1.43 avg=1.91
# [1569 | 7018.32] loss=1.72 avg=1.91
# [1570 | 7022.63] loss=2.00 avg=1.91
# [1571 | 7026.93] loss=2.14 avg=1.91
# [1572 | 7031.24] loss=1.98 avg=1.91
# [1573 | 7035.56] loss=2.19 avg=1.92
# [1574 | 7039.87] loss=1.67 avg=1.91
# [1575 | 7044.13] loss=2.16 avg=1.92
# [1576 | 7048.42] loss=1.44 avg=1.91
# [1577 | 7052.72] loss=1.86 avg=1.91
# [1578 | 7057.03] loss=2.14 avg=1.91
# [1579 | 7061.31] loss=1.37 avg=1.91
# [1580 | 7065.60] loss=2.30 avg=1.91
# [1581 | 7069.89] loss=1.20 avg=1.90
# [1582 | 7074.20] loss=1.91 avg=1.90
# [1583 | 7078.50] loss=1.62 avg=1.90
# [1584 | 7082.80] loss=1.77 avg=1.90
# [1585 | 7087.11] loss=1.46 avg=1.90
# [1586 | 7091.41] loss=1.95 avg=1.90
# [1587 | 7095.71] loss=2.02 avg=1.90
# [1588 | 7100.00] loss=2.13 avg=1.90
# [1589 | 7104.30] loss=1.42 avg=1.90
# [1590 | 7108.58] loss=2.23 avg=1.90
# [1591 | 7112.88] loss=2.17 avg=1.90
# [1592 | 7117.16] loss=1.99 avg=1.90
# [1593 | 7121.47] loss=2.30 avg=1.91
# [1594 | 7125.76] loss=2.07 avg=1.91
# [1595 | 7130.06] loss=1.82 avg=1.91
# [1596 | 7134.35] loss=1.68 avg=1.90
# [1597 | 7138.64] loss=2.46 avg=1.91
# [1598 | 7142.95] loss=1.77 avg=1.91
# [1599 | 7147.24] loss=2.54 avg=1.91
# ======== SAMPLE 1 ========
# I'm tryna watch them get me
# Cameras flash by
# Themes get played out
# Faces are scared and confused
# I'm a product of the world around me
# I'm just a mouse in the face of a world full of mice
# Cameras flash by
# Themes get played out
# Faces are scared and confused
# I'm a product of the world around me
# I'm just a mouse in the face of a world full of mice
# Cameras flash by
# Ain't in the wrong land,
# In the wrong place at the right time
# I promise I'm your worlds only fan
# You'll love me as long as I'm in your streets Cameras flash by
# Themes get played out
# Faces are scared and confused
# I'm a product of the world around me
# I'm just a mouse in the face of a world full of mice
# Cameras flash by
# Themes get played out
# Faces are scared and confused
# I'm a product of the world around me
# I'm just a mouse in the face of a world full of mice
# Cameras flash by
# Themes get played out
# Faces are scared and confused
# I'm a product of the world around me
# I'm just a mouse in the face of a world full of mice I'm so bored, so bored
# Oh, oh, my love, this is the wrong place at the right time
# Cleaning up, drilling down and around my body
# But I'm still so bored by this beat
# 'Cause I'm a mouse in the face of a world full of mice
# They say you're bad, I'm a product of the world around me
# And I'm a product of the world around me
# They say you're bad, but I'm still so bored by this beat
# 'Cause I'm a mouse in the face of a world full of mice
# They say you're bad, but I'm a product of the world around me
# 'Cause I'm a mouse in the face of a world full of mice
# We wanna ride 'em, ride 'em, ride 'em
# We wanna ride 'em, ride 'em, ride 'em
# We wanna ride 'em, ride 'em, ride 'em
# We wanna ride 'em, ride 'em, ride 'em
# We wanna ride 'em, ride 'em, ride 'em
# We wanna ride 'em, ride 'em, ride 'em
# We wanna ride 'em, ride 'em, ride 'em
# We wanna ride 'em, ride 'em, ride 'em I don't think I'll ever see my future
# I know it's past, I'm sure it's far future
# This shit's gonna be hard for the vest
# For some reason I hate the past
# But I still look good in them T-shirts with my name on it
# And the seats are big enough to hold me
# I wanna ride 'em, I wanna ride 'em, I wanna ride 'em
# I wanna ride 'em, I wanna ride 'em, I wanna ride 'em
# I wanna ride 'em, I wanna ride 'em, I wanna ride 'em
# I wanna ride 'em, I wanna ride 'em, I wanna ride 'em
# I wanna ride 'em, I wanna ride 'em, I wanna ride 'em I wanna ride 'em
# 'Cause I can, I can, I can't
# 'Cause I can, I can, I can't
# I can, I can, I can't No more talkin' 'bout whatcha gon' expect
# Whatcha gon' expect 'em, I ain't been heard yet
# Shawty be wildin' and sayin' "Bitch you know we gon' bust you if you want"
# That's right, we'll bust you if you want! 'Cause I can, I can, I can't
# Can I, I can, I can't
# No more talkin' 'bout whatcha gon' expect
# Whatcha gon' expect 'em, I ain't been heard yet
# Shawty be wildin' and sayin' "Bitch you know we gon' bust you if you want!"
# That's right, we'll bust you if you want! 'Cause I can, I can, I can't
# Can I, I can, I can't
# No more talkin' 'bout whatcha gon' expect
# Whatcha gon' expect 'em, I ain't been heard yet
# Shawty be wildin' and sayin' "Bitch you know we gon' bust you if you want!"
# That's right, we'll bust you if you want! Let's take a ride 'cause I can't be bothered
# Let's take a ride 'cause I can't be bothered
# We're on the floor, we're standing here
# Let's take a ride 'cause
#
# [1600 | 7168.90] loss=1.80 avg=1.91
# [1601 | 7173.17] loss=1.54 avg=1.91
# [1602 | 7177.48] loss=1.90 avg=1.91
# [1603 | 7181.79] loss=1.36 avg=1.90
# [1604 | 7186.08] loss=2.15 avg=1.91
# [1605 | 7190.37] loss=1.67 avg=1.90
# [1606 | 7194.66] loss=1.74 avg=1.90
# [1607 | 7198.95] loss=1.65 avg=1.90
# [1608 | 7203.27] loss=2.20 avg=1.90
# [1609 | 7207.58] loss=1.47 avg=1.90
# [1610 | 7211.90] loss=2.52 avg=1.91
# [1611 | 7216.21] loss=1.55 avg=1.90
# [1612 | 7220.53] loss=2.08 avg=1.90
# [1613 | 7224.83] loss=1.75 avg=1.90
# [1614 | 7229.13] loss=1.99 avg=1.90
# [1615 | 7233.44] loss=1.62 avg=1.90
# [1616 | 7237.74] loss=1.74 avg=1.90
# [1617 | 7242.04] loss=1.61 avg=1.90
# [1618 | 7246.34] loss=1.94 avg=1.90
# [1619 | 7250.66] loss=1.79 avg=1.89
# [1620 | 7254.96] loss=2.21 avg=1.90
# [1621 | 7259.26] loss=1.33 avg=1.89
# [1622 | 7263.55] loss=1.49 avg=1.89
# [1623 | 7267.84] loss=1.32 avg=1.88
# [1624 | 7272.13] loss=2.30 avg=1.89
# [1625 | 7276.42] loss=1.97 avg=1.89
# [1626 | 7280.71] loss=1.74 avg=1.89
# [1627 | 7285.00] loss=1.57 avg=1.88
# [1628 | 7289.30] loss=1.75 avg=1.88
# [1629 | 7293.61] loss=2.33 avg=1.89
# [1630 | 7297.93] loss=1.62 avg=1.88
# [1631 | 7302.24] loss=1.47 avg=1.88
# [1632 | 7306.56] loss=1.83 avg=1.88
# [1633 | 7310.87] loss=1.78 avg=1.88
# [1634 | 7315.19] loss=2.41 avg=1.88
# [1635 | 7319.53] loss=2.23 avg=1.89
# [1636 | 7323.87] loss=2.00 avg=1.89
# [1637 | 7328.19] loss=1.41 avg=1.88
# [1638 | 7332.52] loss=1.95 avg=1.88
# [1639 | 7336.83] loss=1.61 avg=1.88
# [1640 | 7341.14] loss=2.05 avg=1.88
# [1641 | 7345.46] loss=2.10 avg=1.89
# [1642 | 7349.77] loss=2.23 avg=1.89
# [1643 | 7354.09] loss=1.92 avg=1.89
# [1644 | 7358.44] loss=1.68 avg=1.89
# [1645 | 7362.77] loss=2.14 avg=1.89
# [1646 | 7367.11] loss=2.05 avg=1.89
# [1647 | 7371.44] loss=1.66 avg=1.89
# [1648 | 7375.77] loss=1.85 avg=1.89
# [1649 | 7380.08] loss=1.76 avg=1.89
# [1650 | 7384.44] loss=1.87 avg=1.89
# [1651 | 7388.77] loss=1.82 avg=1.89
# [1652 | 7393.08] loss=1.29 avg=1.88
# [1653 | 7397.41] loss=1.79 avg=1.88
# [1654 | 7401.72] loss=1.95 avg=1.88
# [1655 | 7406.04] loss=1.94 avg=1.88
# [1656 | 7410.37] loss=1.83 avg=1.88
# [1657 | 7414.71] loss=1.85 avg=1.88
# [1658 | 7419.04] loss=1.99 avg=1.88
# [1659 | 7423.39] loss=1.75 avg=1.88
# [1660 | 7427.71] loss=1.73 avg=1.88
# [1661 | 7432.02] loss=1.57 avg=1.87
# [1662 | 7436.36] loss=1.76 avg=1.87
# [1663 | 7440.69] loss=2.16 avg=1.88
# [1664 | 7445.02] loss=1.32 avg=1.87
# [1665 | 7449.35] loss=1.72 avg=1.87
# [1666 | 7453.69] loss=1.53 avg=1.87
# [1667 | 7458.02] loss=1.98 avg=1.87
# [1668 | 7462.33] loss=1.64 avg=1.86
# [1669 | 7466.65] loss=1.59 avg=1.86
# [1670 | 7470.97] loss=2.03 avg=1.86
# [1671 | 7475.29] loss=1.54 avg=1.86
# [1672 | 7479.60] loss=2.12 avg=1.86
# [1673 | 7483.93] loss=1.48 avg=1.86
# [1674 | 7488.27] loss=1.49 avg=1.86
# [1675 | 7492.59] loss=1.88 avg=1.86
# [1676 | 7496.95] loss=1.86 avg=1.86
# [1677 | 7501.28] loss=1.63 avg=1.85
# [1678 | 7505.59] loss=2.19 avg=1.86
# [1679 | 7509.92] loss=1.66 avg=1.85
# [1680 | 7514.22] loss=1.94 avg=1.86
# [1681 | 7518.56] loss=1.70 avg=1.85
# [1682 | 7522.89] loss=1.71 avg=1.85
# [1683 | 7527.21] loss=2.03 avg=1.85
# [1684 | 7531.53] loss=2.12 avg=1.86
# [1685 | 7535.86] loss=1.36 avg=1.85
# [1686 | 7540.20] loss=2.13 avg=1.86
# [1687 | 7544.54] loss=1.85 avg=1.85
# [1688 | 7548.86] loss=1.39 avg=1.85
# [1689 | 7553.20] loss=2.22 avg=1.85
# [1690 | 7557.52] loss=1.27 avg=1.85
# [1691 | 7561.84] loss=1.73 avg=1.85
# [1692 | 7566.17] loss=1.94 avg=1.85
# [1693 | 7570.51] loss=1.62 avg=1.85
# [1694 | 7574.85] loss=1.77 avg=1.84
# [1695 | 7579.16] loss=1.57 avg=1.84
# [1696 | 7583.48] loss=1.54 avg=1.84
# [1697 | 7587.83] loss=2.07 avg=1.84
# [1698 | 7592.16] loss=1.57 avg=1.84
# [1699 | 7596.47] loss=1.47 avg=1.83
# ======== SAMPLE 1 ========
#  thank my respect to my country
#
# And you said it right out loud:
#
# If a man had his way, we'd go down in flames
#
# But a woman had her way, we won't go down, oh
#
# So I'll say it one last time,
#
# If a man had her way, we'd go down in flames
# Oh, you've seen it a million times, oh
#
# I think I'm going insane
# I'm gonna have to give up on that dream
# And turn to something other
# I'll just sit this way, and burn until I go insane, oh, I will go insane
#
# [Perl]
# Ain't nothing wrong with it
# I don't know why, I don't know why
# I go down to every club in a half-sack, I'm looking at
# The lights are on the edge of the club, I'm looking at
# There's a big sign, the lights are on the edge of the club
# Oh, there's a big sign
# The lights are on the edge of the club
# You can hear it, there's a buzz
# Can you hear it?
#
# [David Bowie]
# I'm trying to find my voice, there's a big sign
# And I'm looking in the mirror,
# There's a big mirror
# With a big red dot on it
# There's a big sign, the lights are on the edge of the club
# Oh, there's a big sign
# The lights are on the edge of the club
# There's a big sign, the lights are on the edge of the club
# Oh, there's a big sign
# The lights are on the edge of the club
# That's all.
# I'm trying to find my voice, there's a big sign
# And I'm looking in the mirror,
# There's a big sign
# With a big red dot on it
# There's a big sign, the lights are on the edge of the club
# Oh, there's a big sign
# The lights are on the edge of the club
# That's all.
# It ain't about sex, I don't mean that. I'm talking about 'how you wanna be'
# How you gonna be a man on my end of this
# If I go to court and get my man back
# We gonna see if it's just another game, like before
# I just don't play that game, cause I play it.
# See I'ma play whatever, if it's a game I gotta play.
# I'll be outa here playing ball, if it's a game I gotta play(Man I gotta play)
# I'll be outa here playing ball, if it's a game I gotta play(Man I gotta play)
# I'll be outa here playing ball, if it's a game I gotta play
# (Man I gotta play)
# I'll be outa here playing ball, if it's a game I gotta play
# (Man I gotta play)
# I'll be outa here playing ball, if it's a game I gotta play
# (Man I gotta play, gotta play)
# (Man I gotta play)
# (Man I gotta play)
# (Man I gotta play)
# (Man I wanna play, gotta play)
# (I gotta play, gotta play)
# (I wanna play, gotta play)
# (I wanna play, gotta play)
# (I wanna play, gotta play)
# (I wanna play, wanna play)
# (Man I gotta play, gotta play) [Hook: The Notorious BIG (Michael)]
# I'm the one
# Who
# I'm like
# Who is it?
# I can't remember the name
# I am the one who got it
# It comes to me
# Never really knowing
# If I'm gonna break it
# I'm like
# Who is it?
# Who is it?
# I can't remember the name
# How long can I keep it up
# Can't remember its happened
# I'm a piece of that puzzle
# With a handful like the shit that it is
# I'm like
# Who is it?
# Who?
# I can't remember the name
# No I'm not a piece of that puzzle
# I'm just like the shit that it is
# With a handful like the shit that it is
# I'm like
# Who is it?
# Who?
# I can't remember the name
# No I'm not a piece of that puzzle
# I'm just like the shit that it is
# With a handful like the shit that it is
# I'm
# Who is it?
# Who?
# I'm like Like a Man Without Attire
# It's Like A Man Without Suit
# It's Like A Man Without Attire
# I'm Like A Man Without Attire
# I'm Like A Man Without Attire
# It's Like A Man Without Attire
# A Man Without Attire
# A Man Without Attire
# A Man Without
#
# [1700 | 7618.48] loss=1.57 avg=1.83
# [1701 | 7622.81] loss=1.37 avg=1.83
# [1702 | 7627.13] loss=1.96 avg=1.83
# [1703 | 7631.46] loss=1.52 avg=1.83
# [1704 | 7635.77] loss=1.95 avg=1.83
# [1705 | 7640.10] loss=1.44 avg=1.82
# [1706 | 7644.43] loss=1.92 avg=1.82
# [1707 | 7648.77] loss=1.98 avg=1.83
# [1708 | 7653.11] loss=1.73 avg=1.82
# [1709 | 7657.45] loss=1.83 avg=1.82
# [1710 | 7661.77] loss=1.76 avg=1.82
# [1711 | 7666.09] loss=1.61 avg=1.82
# [1712 | 7670.43] loss=2.08 avg=1.82
# [1713 | 7674.78] loss=1.72 avg=1.82
# [1714 | 7679.14] loss=1.34 avg=1.82
# [1715 | 7683.48] loss=1.98 avg=1.82
# [1716 | 7687.83] loss=1.52 avg=1.82
# [1717 | 7692.16] loss=2.03 avg=1.82
# [1718 | 7696.52] loss=1.74 avg=1.82
# [1719 | 7700.85] loss=2.01 avg=1.82
# [1720 | 7705.20] loss=1.47 avg=1.82
# [1721 | 7709.54] loss=1.48 avg=1.81
# [1722 | 7713.86] loss=1.80 avg=1.81
# [1723 | 7718.21] loss=1.45 avg=1.81
# [1724 | 7722.54] loss=1.62 avg=1.81
# [1725 | 7726.89] loss=1.81 avg=1.81
# [1726 | 7731.24] loss=1.70 avg=1.81
# [1727 | 7735.58] loss=1.90 avg=1.81
# [1728 | 7739.93] loss=1.85 avg=1.81
# [1729 | 7744.27] loss=1.43 avg=1.80
# [1730 | 7748.63] loss=1.87 avg=1.80
# [1731 | 7752.98] loss=1.89 avg=1.81
# [1732 | 7757.33] loss=1.88 avg=1.81
# [1733 | 7761.67] loss=1.64 avg=1.80
# [1734 | 7766.00] loss=1.77 avg=1.80
# [1735 | 7770.35] loss=1.96 avg=1.81
# [1736 | 7774.67] loss=1.69 avg=1.80
# [1737 | 7778.99] loss=2.09 avg=1.81
# [1738 | 7783.31] loss=1.77 avg=1.81
# [1739 | 7787.66] loss=1.84 avg=1.81
# [1740 | 7791.99] loss=1.86 avg=1.81
# [1741 | 7796.34] loss=1.81 avg=1.81
# [1742 | 7800.67] loss=1.93 avg=1.81
# [1743 | 7805.01] loss=1.76 avg=1.81
# [1744 | 7809.34] loss=1.36 avg=1.80
# [1745 | 7813.67] loss=1.57 avg=1.80
# [1746 | 7818.00] loss=1.46 avg=1.80
# [1747 | 7822.33] loss=1.67 avg=1.80
# [1748 | 7826.67] loss=1.78 avg=1.80
# [1749 | 7830.99] loss=1.90 avg=1.80
# [1750 | 7835.31] loss=1.24 avg=1.79
# [1751 | 7839.64] loss=1.65 avg=1.79
# [1752 | 7843.96] loss=1.91 avg=1.79
# [1753 | 7848.27] loss=1.94 avg=1.79
# [1754 | 7852.60] loss=1.50 avg=1.79
# [1755 | 7856.94] loss=1.66 avg=1.79
# [1756 | 7861.28] loss=1.36 avg=1.79
# [1757 | 7865.60] loss=1.31 avg=1.78
# [1758 | 7869.91] loss=1.82 avg=1.78
# [1759 | 7874.22] loss=1.41 avg=1.78
# interrupted
# Saving checkpoint/run1/model-1760

# %% [markdown]
# save our checkpoints to start training again later

# %%
# !cp -r /content/gpt-2_FT/checkpoint/ /content/drive/My\ Drive/

# %% [markdown]
# use your trained model

# %%
# !cp -r /content/gpt-2_FT/checkpoint/run1/* /content/gpt-2/models/117M/
# Out:
# cp: target '/content/gpt-2/models/117M/' is not a directory

# %% [markdown]
# Conditional samples

# %%
# !python3 src/interactive_conditional_samples.py

# %% [markdown]
# unconditional samples

# %%
# !python3 src/generate_unconditional_samples.py
